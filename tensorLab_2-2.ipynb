# %%
#Placeholder를 이용

import tensorflow as tf

#[1]은 1차원을 의미, Variable = trainable이라고 생각해도 됨. 즉, 학습 중 변할 수 있는 수
W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bais')
X = tf.placeholder(tf.float32, shape=[None])
Y = tf.placeholder(tf.float32, shape=[None])

#Our hypothesis XW + b
hypothesis = X * W + b

# %%
#cost (예측값과 실제값의 차이 합 제곱)
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
#minimize (graph 만들기)
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

# %%
#Launch the graph in a session
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(2001):
    cost_val, W_val, b_val, _ = \
    sess.run([cost,W,b,train],
             feed_dict={X: [1, 2, 3, 4, 5],
                        Y:[2.1, 3.1, 4.1, 5.1, 6.1]})
    
    if step % 20 == 0:
        print(step , ": ",cost_val, W_val, b_val)
# Out:
# 0 :  8.5492184e-07 [1.0005983] [1.0978401]
# 20 :  7.4672533e-07 [1.0005592] [1.0979815]
# 40 :  6.521951e-07 [1.0005226] [1.0981135]
# 60 :  5.696377e-07 [1.0004884] [1.0982368]
# 80 :  4.976281e-07 [1.0004565] [1.0983521]
# 100 :  4.3457007e-07 [1.0004268] [1.09846]
# 120 :  3.796094e-07 [1.0003986] [1.0985607]
# 140 :  3.3158895e-07 [1.0003725] [1.0986549]
# 160 :  2.89559e-07 [1.0003483] [1.0987428]
# 180 :  2.529166e-07 [1.0003254] [1.0988251]
# 200 :  2.2102563e-07 [1.000304] [1.0989019]
# 220 :  1.9302828e-07 [1.0002844] [1.0989736]
# 240 :  1.6853915e-07 [1.0002656] [1.0990407]
# 260 :  1.4721728e-07 [1.0002484] [1.0991036]
# 280 :  1.2863872e-07 [1.000232] [1.0991621]
# 300 :  1.1230577e-07 [1.000217] [1.0992168]
# 320 :  9.818477e-08 [1.0002027] [1.099268]
# 340 :  8.566944e-08 [1.0001894] [1.0993161]
# 360 :  7.4940644e-08 [1.0001771] [1.0993606]
# 380 :  6.538744e-08 [1.0001653] [1.0994024]
# 400 :  5.7112583e-08 [1.0001546] [1.0994416]
# 420 :  4.9893252e-08 [1.0001447] [1.0994781]
# 440 :  4.3592216e-08 [1.0001351] [1.0995121]
# 460 :  3.811175e-08 [1.0001262] [1.099544]
# 480 :  3.3230172e-08 [1.0001181] [1.0995739]
# 500 :  2.902426e-08 [1.0001104] [1.0996017]
# 520 :  2.5382827e-08 [1.0001032] [1.0996279]
# 540 :  2.2214362e-08 [1.0000963] [1.0996517]
# 560 :  1.93863e-08 [1.0000901] [1.0996746]
# 580 :  1.6911509e-08 [1.0000842] [1.099696]
# 600 :  1.4818648e-08 [1.0000789] [1.0997155]
# 620 :  1.2934379e-08 [1.0000737] [1.0997344]
# 640 :  1.1339376e-08 [1.0000689] [1.0997511]
# 660 :  9.8754525e-09 [1.0000641] [1.0997678]
# 680 :  8.617929e-09 [1.0000601] [1.0997828]
# 700 :  7.5246245e-09 [1.0000561] [1.0997971]
# 720 :  6.5573316e-09 [1.0000525] [1.0998107]
# 740 :  5.758932e-09 [1.0000491] [1.0998226]
# 760 :  5.0094173e-09 [1.0000459] [1.0998346]
# 780 :  4.380945e-09 [1.000043] [1.099845]
# 800 :  3.8769485e-09 [1.0000404] [1.0998546]
# 820 :  3.3806828e-09 [1.0000378] [1.0998641]
# 840 :  2.9387137e-09 [1.0000353] [1.0998733]
# 860 :  2.6122051e-09 [1.0000329] [1.0998805]
# 880 :  2.3035227e-09 [1.0000309] [1.0998876]
# 900 :  2.0204425e-09 [1.000029] [1.0998948]
# 920 :  1.7560069e-09 [1.0000271] [1.0999019]
# 940 :  1.5186856e-09 [1.000025] [1.0999091]
# 960 :  1.3103545e-09 [1.0000234] [1.0999154]
# 980 :  1.1589805e-09 [1.000022] [1.0999202]
# 1000 :  1.0287294e-09 [1.0000207] [1.0999249]
# 1020 :  9.0230967e-10 [1.0000194] [1.0999297]
# 1040 :  7.876224e-10 [1.0000181] [1.0999345]
# 1060 :  6.713094e-10 [1.0000168] [1.0999392]
# 1080 :  5.736183e-10 [1.0000155] [1.099944]
# 1100 :  4.972776e-10 [1.0000144] [1.0999478]
# 1120 :  4.5263276e-10 [1.0000138] [1.0999502]
# 1140 :  4.1159182e-10 [1.0000132] [1.0999526]
# 1160 :  3.6848177e-10 [1.0000124] [1.099955]
# 1180 :  3.3157904e-10 [1.0000119] [1.0999573]
# 1200 :  2.9527883e-10 [1.0000112] [1.0999597]
# 1220 :  2.5852387e-10 [1.0000106] [1.0999621]
# 1240 :  2.3107986e-10 [1.0000099] [1.0999645]
# 1260 :  2.0341986e-10 [1.0000092] [1.0999669]
# 1280 :  1.7239472e-10 [1.0000086] [1.0999693]
# 1300 :  1.4915713e-10 [1.000008] [1.0999717]
# 1320 :  1.2132659e-10 [1.0000073] [1.099974]
# 1340 :  1.0284111e-10 [1.0000066] [1.0999764]
# 1360 :  8.326424e-11 [1.0000061] [1.0999787]
# 1380 :  7.504468e-11 [1.0000058] [1.0999795]
# 1400 :  7.504468e-11 [1.0000058] [1.0999795]
# 1420 :  7.504468e-11 [1.0000058] [1.0999795]
# 1440 :  7.504468e-11 [1.0000058] [1.0999795]
# 1460 :  7.504468e-11 [1.0000058] [1.0999795]
# 1480 :  7.504468e-11 [1.0000058] [1.0999795]
# 1500 :  7.504468e-11 [1.0000058] [1.0999795]
# 1520 :  7.504468e-11 [1.0000058] [1.0999795]
# 1540 :  7.504468e-11 [1.0000058] [1.0999795]
# 1560 :  7.504468e-11 [1.0000058] [1.0999795]
# 1580 :  7.504468e-11 [1.0000058] [1.0999795]
# 1600 :  7.504468e-11 [1.0000058] [1.0999795]
# 1620 :  7.504468e-11 [1.0000058] [1.0999795]
# 1640 :  7.504468e-11 [1.0000058] [1.0999795]
# 1660 :  7.504468e-11 [1.0000058] [1.0999795]
# 1680 :  7.504468e-11 [1.0000058] [1.0999795]
# 1700 :  7.504468e-11 [1.0000058] [1.0999795]
# 1720 :  7.504468e-11 [1.0000058] [1.0999795]
# 1740 :  7.504468e-11 [1.0000058] [1.0999795]
# 1760 :  7.504468e-11 [1.0000058] [1.0999795]
# 1780 :  7.504468e-11 [1.0000058] [1.0999795]
# 1800 :  7.504468e-11 [1.0000058] [1.0999795]
# 1820 :  7.504468e-11 [1.0000058] [1.0999795]
# 1840 :  7.504468e-11 [1.0000058] [1.0999795]
# 1860 :  7.504468e-11 [1.0000058] [1.0999795]
# 1880 :  7.504468e-11 [1.0000058] [1.0999795]
# 1900 :  7.504468e-11 [1.0000058] [1.0999795]
# 1920 :  7.504468e-11 [1.0000058] [1.0999795]
# 1940 :  7.504468e-11 [1.0000058] [1.0999795]
# 1960 :  7.504468e-11 [1.0000058] [1.0999795]
# 1980 :  7.504468e-11 [1.0000058] [1.0999795]
# 2000 :  7.504468e-11 [1.0000058] [1.0999795]

# %%
#학습모델 테스트

print(sess.run(hypothesis, feed_dict = {X:[5]}))
print(sess.run(hypothesis, feed_dict = {X:[2.5]}))
print(sess.run(hypothesis, feed_dict = {X:[1.5,3.5]}))
# Out:
# [6.1000085]
# [3.5999942]
# [2.5999885 4.6      ]
