# %%
import tensorflow as tf

X = [1,2,3]
Y = [1,2,3]

W = tf.Variable(5.0)

hypothesis = X * W

cost = tf.reduce_mean(tf.square(hypothesis - Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.1)

train = optimizer.minimize(cost)

sess = tf.Session()

sess.run(tf.global_variables_initializer())

for step in range(100):
    print('step: ', step, ': ', sess.run(W))
    sess.run(train)
# Out:
# step:  0 :  5.0
# step:  1 :  1.2666664
# step:  2 :  1.0177778
# step:  3 :  1.0011852
# step:  4 :  1.000079
# step:  5 :  1.0000052
# step:  6 :  1.0000004
# step:  7 :  1.0
# step:  8 :  1.0
# step:  9 :  1.0
# step:  10 :  1.0
# step:  11 :  1.0
# step:  12 :  1.0
# step:  13 :  1.0
# step:  14 :  1.0
# step:  15 :  1.0
# step:  16 :  1.0
# step:  17 :  1.0
# step:  18 :  1.0
# step:  19 :  1.0
# step:  20 :  1.0
# step:  21 :  1.0
# step:  22 :  1.0
# step:  23 :  1.0
# step:  24 :  1.0
# step:  25 :  1.0
# step:  26 :  1.0
# step:  27 :  1.0
# step:  28 :  1.0
# step:  29 :  1.0
# step:  30 :  1.0
# step:  31 :  1.0
# step:  32 :  1.0
# step:  33 :  1.0
# step:  34 :  1.0
# step:  35 :  1.0
# step:  36 :  1.0
# step:  37 :  1.0
# step:  38 :  1.0
# step:  39 :  1.0
# step:  40 :  1.0
# step:  41 :  1.0
# step:  42 :  1.0
# step:  43 :  1.0
# step:  44 :  1.0
# step:  45 :  1.0
# step:  46 :  1.0
# step:  47 :  1.0
# step:  48 :  1.0
# step:  49 :  1.0
# step:  50 :  1.0
# step:  51 :  1.0
# step:  52 :  1.0
# step:  53 :  1.0
# step:  54 :  1.0
# step:  55 :  1.0
# step:  56 :  1.0
# step:  57 :  1.0
# step:  58 :  1.0
# step:  59 :  1.0
# step:  60 :  1.0
# step:  61 :  1.0
# step:  62 :  1.0
# step:  63 :  1.0
# step:  64 :  1.0
# step:  65 :  1.0
# step:  66 :  1.0
# step:  67 :  1.0
# step:  68 :  1.0
# step:  69 :  1.0
# step:  70 :  1.0
# step:  71 :  1.0
# step:  72 :  1.0
# step:  73 :  1.0
# step:  74 :  1.0
# step:  75 :  1.0
# step:  76 :  1.0
# step:  77 :  1.0
# step:  78 :  1.0
# step:  79 :  1.0
# step:  80 :  1.0
# step:  81 :  1.0
# step:  82 :  1.0
# step:  83 :  1.0
# step:  84 :  1.0
# step:  85 :  1.0
# step:  86 :  1.0
# step:  87 :  1.0
# step:  88 :  1.0
# step:  89 :  1.0
# step:  90 :  1.0
# step:  91 :  1.0
# step:  92 :  1.0
# step:  93 :  1.0
# step:  94 :  1.0
# step:  95 :  1.0
# step:  96 :  1.0
# step:  97 :  1.0
# step:  98 :  1.0
# step:  99 :  1.0
