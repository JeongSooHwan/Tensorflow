# %%
import tensorflow as tf

# %%
x_train = [1,2,3,4,5,6,7]
y_train = [2,4,6,8,10,12,14]

# %%
W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bais')

# %%
hypothesis = W * x_train + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis-y_train))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)

# %%
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for i in range(2001):
    sess.run(train)
    if i % 20 == 0:
        print(i,sess.run(cost),sess.run(W),sess.run(b))
# Out:
# 0 45.789265 [0.3456807] [0.7145514]
# 20 0.17409997 [1.8115926] [0.93282396]
# 40 0.14923838 [1.8255913] [0.8636612]
# 60 0.12792696 [1.8385237] [0.79962116]
# 80 0.10965886 [1.8504971] [0.74032956]
# 100 0.093999445 [1.8615828] [0.68543434]
# 120 0.080576286 [1.8718462] [0.63460964]
# 140 0.06906982 [1.8813487] [0.5875537]
# 160 0.059206564 [1.8901467] [0.5439869]
# 180 0.0507519 [1.8982923] [0.5036505]
# 200 0.04350453 [1.9058338] [0.4663051]
# 220 0.037291985 [1.9128163] [0.43172884]
# 240 0.03196669 [1.9192808] [0.39971632]
# 260 0.02740182 [1.9252661] [0.37007752]
# 280 0.023488829 [1.9308077] [0.34263647]
# 300 0.020134542 [1.9359382] [0.3172301]
# 320 0.017259309 [1.9406884] [0.2937076]
# 340 0.014794676 [1.9450864] [0.2719293]
# 360 0.012681956 [1.9491582] [0.2517659]
# 380 0.0108710015 [1.9529281] [0.23309755]
# 400 0.009318585 [1.9564184] [0.21581346]
# 420 0.007987893 [1.95965] [0.19981097]
# 440 0.006847226 [1.962642] [0.18499507]
# 460 0.0058694268 [1.965412] [0.17127778]
# 480 0.0050312504 [1.9679767] [0.15857765]
# 500 0.0043127947 [1.9703512] [0.14681914]
# 520 0.0036969131 [1.9725497] [0.13593256]
# 540 0.003168985 [1.974585] [0.12585321]
# 560 0.0027164747 [1.9764696] [0.11652122]
# 580 0.002328538 [1.9782144] [0.10788118]
# 600 0.00199602 [1.9798298] [0.09988183]
# 620 0.001710987 [1.9813254] [0.09247565]
# 640 0.0014666554 [1.98271] [0.08561864]
# 660 0.0012572119 [1.9839921] [0.07927007]
# 680 0.0010776921 [1.9851792] [0.0733922]
# 700 0.000923799 [1.986278] [0.06795016]
# 720 0.0007918664 [1.9872955] [0.06291166]
# 740 0.0006787907 [1.9882376] [0.05824677]
# 760 0.0005818676 [1.9891098] [0.05392781]
# 780 0.0004987774 [1.9899173] [0.04992908]
# 800 0.00042755026 [1.990665] [0.04622686]
# 820 0.00036649007 [1.9913571] [0.04279914]
# 840 0.0003141531 [1.991998] [0.03962567]
# 860 0.0002692937 [1.9925914] [0.03668743]
# 880 0.0002308404 [1.9931407] [0.03396705]
# 900 0.00019787546 [1.9936492] [0.03144842]
# 920 0.00016961641 [1.9941201] [0.0291165]
# 940 0.00014539702 [1.9945562] [0.02695751]
# 960 0.00012463338 [1.9949598] [0.0249586]
# 980 0.000106837004 [1.9953336] [0.02310793]
# 1000 9.157897e-05 [1.9956796] [0.02139449]
# 1020 7.850372e-05 [1.996] [0.0198081]
# 1040 6.7292836e-05 [1.9962965] [0.0183393]
# 1060 5.768281e-05 [1.9965712] [0.01697945]
# 1080 4.9445927e-05 [1.9968253] [0.01572042]
# 1100 4.2384614e-05 [1.9970608] [0.01455476]
# 1120 3.633284e-05 [1.9972788] [0.0134755]
# 1140 3.1144078e-05 [1.9974805] [0.01247628]
# 1160 2.6696991e-05 [1.9976673] [0.01155115]
# 1180 2.2883705e-05 [1.9978403] [0.01069469]
# 1200 1.961514e-05 [1.9980004] [0.0099017]
# 1220 1.6815338e-05 [1.9981487] [0.00916753]
# 1240 1.4413878e-05 [1.998286] [0.00848781]
# 1260 1.2355586e-05 [1.9984131] [0.00785843]
# 1280 1.0591063e-05 [1.9985306] [0.00727576]
# 1300 9.078918e-06 [1.9986396] [0.00673633]
# 1320 7.782162e-06 [1.9987406] [0.00623684]
# 1340 6.671306e-06 [1.9988339] [0.00577443]
# 1360 5.7193397e-06 [1.9989203] [0.0053463]
# 1380 4.902592e-06 [1.9990004] [0.00494986]
# 1400 4.2026973e-06 [1.9990745] [0.00458286]
# 1420 3.6022757e-06 [1.9991431] [0.00424306]
# 1440 3.087904e-06 [1.9992068] [0.00392847]
# 1460 2.6467023e-06 [1.9992656] [0.00363716]
# 1480 2.2691518e-06 [1.9993199] [0.00336749]
# 1500 1.944856e-06 [1.9993703] [0.00311779]
# 1520 1.6672413e-06 [1.9994171] [0.00288661]
# 1540 1.4291679e-06 [1.9994603] [0.00267257]
# 1560 1.2247638e-06 [1.9995003] [0.0024744]
# 1580 1.0501432e-06 [1.9995373] [0.00229093]
# 1600 9.002779e-07 [1.9995717] [0.0021211]
# 1620 7.7148985e-07 [1.9996035] [0.00196381]
# 1640 6.615146e-07 [1.9996328] [0.00181817]
# 1660 5.670632e-07 [1.99966] [0.00168336]
# 1680 4.8620325e-07 [1.9996852] [0.00155855]
# 1700 4.1663944e-07 [1.9997085] [0.00144297]
# 1720 3.5701464e-07 [1.9997302] [0.00133599]
# 1740 3.06115e-07 [1.9997501] [0.00123696]
# 1760 2.625305e-07 [1.9997687] [0.00114525]
# 1780 2.2506467e-07 [1.9997859] [0.00106038]
# 1800 1.9286283e-07 [1.9998018] [0.00098172]
# 1820 1.6536741e-07 [1.9998164] [0.00090899]
# 1840 1.4179571e-07 [1.99983] [0.00084158]
# 1860 1.2146211e-07 [1.9998426] [0.00077927]
# 1880 1.0408836e-07 [1.9998544] [0.00072147]
# 1900 8.929734e-08 [1.999865] [0.00066796]
# 1920 7.6533134e-08 [1.999875] [0.00061852]
# 1940 6.559936e-08 [1.9998844] [0.00057277]
# 1960 5.626723e-08 [1.999893] [0.00053027]
# 1980 4.8235645e-08 [1.9999008] [0.00049099]
# 2000 4.1327763e-08 [1.9999082] [0.00045462]
