# %%
import tensorflow as tf
import numpy as np

# %%
# X와 Y의 데이터
x_train = [1,2,3]
y_train = [1,2,3]

#[1]은 1차원을 의미, Variable = trainable이라고 생각해도 됨. 즉, 학습 중 변할 수 있는 수
W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bais')

#Our hypothesis XW + b
hypothesis = x_train * W + b

# %%
#cost (예측값과 실제값의 차이 합 제곱)
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %%
#minimize (graph 만들기)
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

# %%
#Launch the graph in a session
sess = tf.Session()

#Initializes global variables in the graph
sess.run(tf.global_variables_initializer())

# %%
#Fit the line
for step in range(2001):
    sess.run(train)
    if(step % 20 == 0):
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 16.461884 [-0.49469444] [-0.8800395]
# 20 0.15373893 [0.92802835] [-0.2437236]
# 40 0.0054660863 [1.0601927] [-0.17561807]
# 60 0.0037479748 [1.0696263] [-0.16197032]
# 80 0.0033929432 [1.0675218] [-0.15384464]
# 100 0.0030814272 [1.0644598] [-0.14656556]
# 120 0.0027985936 [1.061441] [-0.13967289]
# 140 0.0025417288 [1.0585544] [-0.13310832]
# 160 0.0023084325 [1.0558027] [-0.12685265]
# 180 0.0020965552 [1.0531801] [-0.12089102]
# 200 0.0019041282 [1.050681] [-0.1152096]
# 220 0.0017293656 [1.0482991] [-0.1097952]
# 240 0.0015706378 [1.0460292] [-0.10463521]
# 260 0.0014264705 [1.043866] [-0.09971774]
# 280 0.0012955472 [1.0418047] [-0.09503143]
# 300 0.0011766419 [1.0398401] [-0.09056541]
# 320 0.0010686431 [1.0379676] [-0.08630916]
# 340 0.00097055687 [1.0361832] [-0.08225292]
# 360 0.0008814792 [1.0344828] [-0.07838738]
# 380 0.0008005773 [1.0328623] [-0.0747035]
# 400 0.0007270937 [1.0313177] [-0.07119271]
# 420 0.0006603604 [1.0298458] [-0.06784687]
# 440 0.0005997485 [1.0284433] [-0.06465828]
# 460 0.00054470025 [1.0271065] [-0.06161959]
# 480 0.00049470476 [1.0258327] [-0.05872369]
# 500 0.00044929844 [1.0246186] [-0.05596391]
# 520 0.00040806062 [1.0234617] [-0.05333384]
# 540 0.00037060984 [1.0223591] [-0.05082738]
# 560 0.00033659136 [1.0213083] [-0.04843874]
# 580 0.00030569822 [1.0203068] [-0.0461623]
# 600 0.00027763788 [1.0193523] [-0.04399273]
# 620 0.00025215477 [1.0184429] [-0.04192515]
# 640 0.00022901047 [1.0175762] [-0.0399548]
# 660 0.00020799121 [1.0167501] [-0.03807706]
# 680 0.00018890026 [1.015963] [-0.03628755]
# 700 0.00017156366 [1.0152128] [-0.03458218]
# 720 0.00015581718 [1.0144978] [-0.03295694]
# 740 0.00014151567 [1.0138165] [-0.03140806]
# 760 0.00012852547 [1.0131671] [-0.02993197]
# 780 0.00011672738 [1.0125483] [-0.02852526]
# 800 0.000106015454 [1.0119586] [-0.02718472]
# 820 9.628527e-05 [1.0113966] [-0.02590712]
# 840 8.744698e-05 [1.0108609] [-0.0246896]
# 860 7.942216e-05 [1.0103507] [-0.02352932]
# 880 7.2132905e-05 [1.0098643] [-0.02242359]
# 900 6.551185e-05 [1.0094006] [-0.02136975]
# 920 5.9498867e-05 [1.0089588] [-0.02036546]
# 940 5.403716e-05 [1.0085378] [-0.01940835]
# 960 4.907741e-05 [1.0081366] [-0.01849624]
# 980 4.4573113e-05 [1.0077542] [-0.01762702]
# 1000 4.0482064e-05 [1.0073898] [-0.01679863]
# 1020 3.676763e-05 [1.0070425] [-0.01600916]
# 1040 3.3392098e-05 [1.0067115] [-0.01525682]
# 1060 3.0327936e-05 [1.006396] [-0.01453982]
# 1080 2.7544376e-05 [1.0060955] [-0.01385647]
# 1100 2.5015906e-05 [1.0058091] [-0.01320529]
# 1120 2.2719856e-05 [1.0055361] [-0.01258471]
# 1140 2.063457e-05 [1.0052758] [-0.0119933]
# 1160 1.8741266e-05 [1.0050279] [-0.01142966]
# 1180 1.7020047e-05 [1.0047916] [-0.01089253]
# 1200 1.5458574e-05 [1.0045666] [-0.01038062]
# 1220 1.4039368e-05 [1.004352] [-0.00989283]
# 1240 1.2750953e-05 [1.0041474] [-0.00942794]
# 1260 1.15813045e-05 [1.0039525] [-0.00898491]
# 1280 1.05179615e-05 [1.0037668] [-0.00856269]
# 1300 9.552968e-06 [1.0035897] [-0.00816031]
# 1320 8.676271e-06 [1.0034212] [-0.00777685]
# 1340 7.87993e-06 [1.0032604] [-0.00741142]
# 1360 7.1567424e-06 [1.0031071] [-0.00706312]
# 1380 6.499898e-06 [1.0029612] [-0.00673122]
# 1400 5.9037284e-06 [1.002822] [-0.00641493]
# 1420 5.361717e-06 [1.0026894] [-0.00611352]
# 1440 4.8696415e-06 [1.002563] [-0.00582623]
# 1460 4.4225585e-06 [1.0024426] [-0.00555243]
# 1480 4.0169907e-06 [1.0023279] [-0.00529154]
# 1500 3.648153e-06 [1.0022185] [-0.00504291]
# 1520 3.3131703e-06 [1.0021142] [-0.00480594]
# 1540 3.0095268e-06 [1.0020149] [-0.00458012]
# 1560 2.7331964e-06 [1.0019202] [-0.00436492]
# 1580 2.4824396e-06 [1.0018301] [-0.00415984]
# 1600 2.254684e-06 [1.001744] [-0.00396442]
# 1620 2.0477335e-06 [1.001662] [-0.00377817]
# 1640 1.8600595e-06 [1.001584] [-0.00360069]
# 1660 1.6891623e-06 [1.0015094] [-0.00343151]
# 1680 1.5344298e-06 [1.0014387] [-0.00327027]
# 1700 1.3935127e-06 [1.001371] [-0.00311664]
# 1720 1.2656902e-06 [1.0013067] [-0.00297022]
# 1740 1.1494348e-06 [1.0012454] [-0.00283071]
# 1760 1.0442433e-06 [1.001187] [-0.00269777]
# 1780 9.4843404e-07 [1.0011312] [-0.00257109]
# 1800 8.613653e-07 [1.001078] [-0.00245033]
# 1820 7.823431e-07 [1.0010275] [-0.00233529]
# 1840 7.106553e-07 [1.0009793] [-0.00222569]
# 1860 6.4557713e-07 [1.0009333] [-0.0021212]
# 1880 5.863581e-07 [1.0008895] [-0.0020216]
# 1900 5.325689e-07 [1.0008478] [-0.00192668]
# 1920 4.8375733e-07 [1.0008079] [-0.00183624]
# 1940 4.3941432e-07 [1.0007697] [-0.00175007]
# 1960 3.991986e-07 [1.000734] [-0.00166798]
# 1980 3.6260897e-07 [1.0006996] [-0.00158969]
# 2000 3.2928816e-07 [1.0006665] [-0.00151513]
